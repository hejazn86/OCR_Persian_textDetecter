# %% [markdown]
# <a href="https://colab.research.google.com/github/hejazn86/OCR_Persian_textDetecter/blob/master/OCR_experimental_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
#craeting blank image and putting English text on it
import cv2
print(cv2.__version__)
import numpy
import matplotlib.pyplot as plt


img = np.zeros((300, 300, 3), np.uint8)
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 'Hejaz',(80, 150), font, 2, (255, 255, 255), 6, cv2.LINE_AA )

plt.imshow(img)
# Out:
# 4.1.2

# %%
# creating a list of words and creating blank images to put these words on them
words = ['hello', 'how', 'many', 'time', 'spend']
images = []
for i in range(0, len(words)):
    images.append(np.zeros((300, 300, 3), np.uint8))
    for img in images:
      for word in words:
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(images[i], words[i],(60, 150), font, 2, (255, 255, 255), 5, cv2.LINE_AA )

#image = np.array(images)
#plt.imshow(images[3])
#print(images[1])
plt.figure(figsize=(30, 21))
plt.subplot(511).imshow(images[0])
plt.subplot(512).imshow(images[1])
plt.subplot(513).imshow(images[2])
plt.subplot(514).imshow(images[3])
plt.subplot(515).imshow(images[4])
plt.show()

# %%
#putting Arabic/Persian text on image using pillow, arabic_reshaper and bidi 
import PIL
import numpy as np
# !pip install python-bidi
# !pip install arabic_reshaper

from bidi.algorithm import get_display
from PIL import ImageFont, Image, ImageDraw
import arabic_reshaper
import matplotlib.pyplot as plt 

text = ' موزه تهران'
reshaped_text = arabic_reshaper.reshape(text)
bidi_text = get_display(reshaped_text)

fontFile = "/drive/My Drive/Colab Notebooks/Sahel Regular.ttf"
font = ImageFont.truetype(fontFile, 200)

img = Image.open('/drive/My Drive/Colab Notebooks/beauty.jpg') 
draw = ImageDraw.Draw(img)
draw.multiline_text((500, 500), bidi_text, font=font, fill='blue')
img.save(text+'.png')
plt.imshow(img)

# %%
# creating blank image using pillow and putting Persian text on it 
# !pip install python-bidi
# !pip install arabic_reshaper

import PIL
import cv2
import numpy as np
from bidi.algorithm import get_display
from PIL import ImageFont, Image, ImageDraw
import arabic_reshaper
import matplotlib.pyplot as plt 

text = 'حجاز نواصر'
reshaped_text = arabic_reshaper.reshape(text)
bidi_text = get_display(reshaped_text)
fontFile = "/drive/My Drive/Colab Notebooks/Sahel Regular.ttf"
font = ImageFont.truetype(fontFile, 30)

img = Image.new('RGB', (300, 300), (255, 255, 255))
#img.save('img.png', "PNG")

draw = ImageDraw.Draw(img)
draw.multiline_text((100, 150), bidi_text, font=font, fill='blue')
#img.save(text+'.png')
plt.imshow(img)
#print(bidi_text)

# %%
# !pip install python-bidi
# !pip install arabic_reshaper

import PIL
import cv2
import numpy as np
from bidi.algorithm import get_display
from PIL import ImageFont, Image, ImageDraw
import arabic_reshaper
import matplotlib.pyplot as plt 

fontFile = "/drive/My Drive/Colab Notebooks/Sahel Regular.ttf"

def bidi_text(word):
  reshaped_text = arabic_reshaper.reshape(word)
  bidi_word = get_display(reshaped_text)
  return bidi_word

def create_image():
  image = Image.new('RGB', (300, 300), (255, 255, 255))
  return image

def putting_text(img, bidi_word):
      fontFile = "/drive/My Drive/Colab Notebooks/Sahel Regular.ttf"  
      font = ImageFont.truetype(fontFile, 30)
      draw = ImageDraw.Draw(img)
      draw.text((100, 150), bidi_word, font=font, fill='blue')
      img.save(text+'.png')
      return img


'''word = 'حجاز'
text = bidi_text(word)
img = create_image()
image = putting_text(img, text)
plt.imshow(image)'''

words = ['سلام', 'احترام', 'موفقیت', 'تلاش']
bidi_words = []
images = []
image_text = []

for word in words:
  bidi_words.append(bidi_text(word))
  for i in range(0, len(bidi_words)):
    images.append(create_image())
    for x in range(0, len(images)):
      image_text.append(putting_text(images[i], bidi_words[i]))


plt.subplot(221).imshow(image_text[0])
plt.subplot(222).imshow(image_text[1])
plt.subplot(223).imshow(image_text[2])
plt.subplot(224).imshow(image_text[3])

print(len(bidi_words))
# Out:
# ...
# 4

# %%
'''!pip install freetype-py
import cv2
import numpy as np

img = np.zeros((300, 300, 3), dtype=np.uint8)

ftype = cv2.freetype.creatFreeType2()
ftype.loadFontData(fontFileName='Sahel Regular.ttf', id=0)

ftype.putText(img, 'سلام', (80, 150), 60, (255, 255, 255), -1, cv2.LINE_AA, bottomLeftOrigin=True)'''
